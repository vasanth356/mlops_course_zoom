# %%
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2023-03-01 00:25:10   2023-03-01 00:35:47                  N
# 1         2  2023-03-01 00:14:29   2023-03-01 00:25:04                  N
# 2         2  2023-03-01 00:14:29   2023-03-01 00:25:04                  N
# 3         2  2023-02-28 22:59:46   2023-02-28 23:08:38                  N
# 4         2  2023-03-01 00:54:03   2023-03-01 01:03:14                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            82           196              1.0           2.36
# 1         1.0             7             7              1.0           0.78
# 2         1.0             7             7              1.0           0.78
# 3         1.0           166            74              1.0           1.66
# 4         1.0           236           229              1.0           3.14
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %% [markdown]
# # Question Install MLflow
# ## What's the version that you have? : Answer is 2.17.2

# %%
# question 1
Image(filename="./data/experiments/question1.png")

# %% [markdown]
# # Q2. Download and preprocess the data
# ## How many files were saved to OUTPUT_FOLDER?  : answer is 4

# %%
# question 2
Image(filename="./data/experiments/question2.png")

# %% [markdown]
# # Q3. Train a model with autolog
#
# ## What is the value of the min_samples_split parameter:  Answer is 2

# %%
#quesion3:
Image(filename="./data/experiments/question3.png")

# %% [markdown]
# # question 4: Launch the tracking server locally
#
# ### Answer is the default-artifact-root

# %%
Image(filename="./data/experiments/question4.png")

# %% [markdown]
# # Q5. Tune model hyperparameters
# ## What's the best validation RMSE that you got? Answer is 5.355

# %%
Image(filename="./data/experiments/question5.png")

# %% [markdown]
# # Q6. Promote the best model to the model registry
# ## What is the test RMSE of the best model?: Answer is 5.567

# %%
Image(filename="./data/experiments/question6.png")
